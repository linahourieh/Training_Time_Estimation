# %%
#! pip install pandas
import pandas as pd
import plotly.express as px
import plotly.figure_factory as ff

# %%
import pandas as pd
import glob
import os

path = '/home/lina/PycharmProjects/Project1/Data' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))

df = pd.concat((pd.read_csv(f) for f in all_files[::-1]), ignore_index=True)
df.drop(columns=['Unnamed: 0'], inplace= True)

# %%
df.shape
# Out:
# (10220, 5)

# %%
#df = pd.read_csv('/home/lina/PycharmProjects/Carrots/api/data2000.csv', index_col=0)

# %%
df.tail()
# Out:
#           m  n  kernel  n_iter  training_time
# 10215  1110  9       0    1817       0.044878
# 10216  1110  6       1     882       0.054213
# 10217  1110  6       0    1622       0.049746
# 10218  1110  3       1     742       0.057577
# 10219  1110  3       0     756       0.037756

# %%
df.head()
# Out:
#       m   n  kernel  n_iter  training_time
# 0  1100  30       1     958       0.053595
# 1  1100  30       0   44617       0.103748
# 2  1100  27       1     943       0.051384
# 3  1100  27       0   33948       0.088973
# 4  1100  24       1     932       0.048373

# %%
df.describe()
# Out:
#                   m             n        kernel         n_iter  training_time
# count  10220.000000  10220.000000  10220.000000   10220.000000   10220.000000
# mean    2551.956947     16.500000      0.500000   19689.313699       0.421133
# std     1472.475751      8.617266      0.500024   31710.968663       0.404353
# min       10.000000      3.000000      0.000000       5.000000       0.000524
# 25%     1270.000000      9.000000      0.000000    1856.750000       0.073990
# 50%     2550.000000     16.500000      0.500000    3618.000000       0.315645
# 75%     3830.000000     24.000000      1.000000   24859.250000       0.672307
# max     5100.000000     30.000000      1.000000  250789.000000       2.119709

# %%
px.colors.sequential.Tealgrn
# Out:
# ['rgb(176, 242, 188)',
#  'rgb(137, 232, 172)',
#  'rgb(103, 219, 165)',
#  'rgb(76, 200, 163)',
#  'rgb(56, 178, 163)',
#  'rgb(44, 152, 160)',
#  'rgb(37, 125, 152)']

# %%
class ImagesBank:
    def __init__(self, dataframe) -> None:
        self.df = dataframe
        self.scatter = None
        self.displot = None
        self.boxplot = None
        self.bubble = None

    def draw_bubble(self, x: str, y: str, color: str, log_x=False, title= None):
        fig = px.scatter(self.df, x=x, y=y, color=color, log_x=False, size_max=6, color_continuous_scale='tealgrn')
        self.layout(fig)
        self.bubble = fig
        return self.bubble
    

    def draw_box(self, y: str):
        fig = px.box(self.df, y=y, color_discrete_sequence=px.colors.sequential.Tealgrn[3:])
        self.layout(fig)
        self.boxplot = fig
        return self.boxplot


    def draw_dist(self, column: str, binsize = 0.001, curve= 'normal'):
        hist_data = [self.df[column]]
        label = [column]
        fig = ff.create_distplot(hist_data, label, bin_size=binsize, curve_type=curve, colors=px.colors.sequential.Tealgrn[3:])
        self.layout(fig)
        self.displot = fig
        return self.displot

    def layout(self, figure):
        figure.update_layout(
                            title_x=0.16,
                            width=600,
                            height=600,
                            legend=dict(
                                yanchor="top",
                                y=1.1,
                                xanchor="left",
                                x=0.01),
                            template='plotly_white',
                            plot_bgcolor="rgb(255,255,255)",
                            font=dict(family="Courier New, monospace",
                                      size=14))
    def add_titles(self, figure, title=None, x_title=None, y_title=None):
        figure.update_layout(title_text=title,
                            xaxis_title=x_title,
                            yaxis_title=y_title)
        return figure

# %%
df_whole = ImagesBank(df)
df_whole.draw_bubble(x="m", y="training_time", color="n")
df_whole.add_titles(df_whole.bubble, 'Bubble Plot', x_title='m', y_title='training time').show()

# %%
df_whole.draw_box('training_time')

# %%
df_whole.draw_dist(column='training_time').show()

# %%
import plotly.figure_factory as ff
import numpy as np
np.random.seed(1)

hist_data = [df['training_time']]
group_labels = ['m'] # name of the dataset
fig = ff.create_distplot(hist_data, group_labels, bin_size=0.001, curve_type='kde')
fig.update_layout(title_text='scatter',
                                 title_x=0.16,
                                 xaxis_title="m",
                                 yaxis_title="training time",
                                 width=600,
                                 height=600,
                                 legend=dict(
                                     yanchor="top",
                                     y=1.1,
                                     xanchor="left",
                                     x=0.01),
                                 template='plotly_white',
                                 plot_bgcolor="rgb(255,255,255)",
                                 font=dict(family="Courier New, monospace",
                                           size=14))
fig.show()

# %%
df[df.kernel == 1].describe()

# %%
df[df.kernel == 1]

# %%
kernel0 = df[df.kernel == 0]
kernel1 = df[df.kernel == 1]

# %%
fig = px.scatter(x = kernel0.loc[:,'m'], y = kernel0.loc[:, 'training_time'] )
fig.update_layout(title_text='scatter',
                                 title_x=0.16,
                                 xaxis_title="m",
                                 yaxis_title="training time",
                                 width=600,
                                 height=600,
                                 legend=dict(
                                     yanchor="top",
                                     y=1.1,
                                     xanchor="left",
                                     x=0.01),
                                 template='plotly_white',
                                 plot_bgcolor="rgb(255,255,255)",
                                 font=dict(family="Courier New, monospace",
                                           size=14))
fig.show()

# %%
fig = px.scatter(kernel0, x="m", y="training_time", color="n", log_x=False, size_max=6, color_continuous_scale='tealgrn')
fig.update_layout(title_text='scatter',
                                 title_x=0.16,
                                 xaxis_title="m",
                                 yaxis_title="training time",
                                 width=1200,
                                 height=700,
                                 legend=dict(
                                     yanchor="top",
                                     y=1.1,
                                     xanchor="left",
                                     x=0.01),
                                 template='plotly_white',
                                 plot_bgcolor="rgb(255,255,255)",
                                 font=dict(family="Courier New, monospace",
                                           size=14))
fig.show()

# %%
fig = px.scatter(k0c, x="m", y="training_time", color="n", log_x=False, size_max=6, color_continuous_scale='tealgrn')
fig.update_layout(title_text='scatter',
                                 title_x=0.16,
                                 xaxis_title="m",
                                 yaxis_title="training time",
                                 width=1200,
                                 height=700,
                                 legend=dict(
                                     yanchor="top",
                                     y=1.1,
                                     xanchor="left",
                                     x=0.01),
                                 template='plotly_white',
                                 plot_bgcolor="rgb(255,255,255)",
                                 font=dict(family="Courier New, monospace",
                                           size=14))
fig.show()

# %%
kernel1[(kernel1.training_time > 0.2)].index

# %%
kernel1.drop(list(kernel1[(kernel1.training_time > 0.2)].index), inplace=True)

# %%
fig = px.scatter(kernel1, x="m", y="training_time", color="n", log_x=False, size_max=6, color_continuous_scale='tealgrn')
fig.update_layout(title_text='scatter',
                                 title_x=0.16,
                                 xaxis_title="m",
                                 yaxis_title="training time",
                                 width=1200,
                                 height=700,
                                 legend=dict(
                                     yanchor="top",
                                     y=1.1,
                                     xanchor="left",
                                     x=0.01),
                                 template='plotly_white',
                                 plot_bgcolor="rgb(255,255,255)",
                                 font=dict(family="Courier New, monospace",
                                           size=14))
fig.show()

# %%
kernel1.drop(list(kernel1[(kernel1.m == 883)].index), inplace=True)

# %%
kernel1.drop(list(kernel1[(kernel1.m == 862) & (kernel1.n == 48)].index), inplace=True)

# %%
kernel1.describe()

# %%
fig = px.box(k0c, y="training_time")
fig.update_layout(title_text='scatter',
                                 title_x=0.16,
                                 xaxis_title="m",
                                 yaxis_title="training time",
                                 width=1200,
                                 height=700,
                                 legend=dict(
                                     yanchor="top",
                                     y=1.1,
                                     xanchor="left",
                                     x=0.01),
                                 template='plotly_white',
                                 plot_bgcolor="rgb(255,255,255)",
                                 font=dict(family="Courier New, monospace",
                                           size=14))
fig.show()

# %%
q = kernel1["training_time"].quantile(0.75)
df_filtered = kernel1[(kernel1["training_time"] < q)]
df_filtered

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
k1c = remove_outlier(kernel1, col_name='training_time')
k0c = remove_outlier(kernel0, col_name='training_time')

# %%
data_no_outlier = pd.concat([k1c,k0c])

# %%
data_no_outlier.describe()

# %%
mu, sigma = 0, 0.1
s = np.random.normal(mu, sigma, size=(1000)) 
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %%
mu=0.0
std = 0.90 * np.std(s) # for %5 Gaussian noise
def gaussian_noise(x,mu,std):
    noise = np.random.normal(mu, std, size = x.shape)
    x_noisy = x + noise
    return x_noisy

x_noisy = gaussian_noise(s, mu=mu, std=std) 

count, bins, ignored = plt.hist(x_noisy, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()
